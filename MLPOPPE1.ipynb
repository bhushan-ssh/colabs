# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushan-ssh/colabs/blob/main/MLPOPPE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd



import numpy as np

# %%
df=pd.read_csv('/NPPE1_Preprocessing1.csv')

# %%
df.shape
# Out:
# (4000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CRIM          4000 non-null   float64
#  1   ZN            4000 non-null   float64
#  2   INDUS         4000 non-null   float64
#  3   POLINDEX      4000 non-null   float64
#  4   RM            4000 non-null   float64
#  5   AGE           4000 non-null   float64
#  6   DIS           4000 non-null   float64
#  7   HIGHWAYCOUNT  4000 non-null   int64
#  8   TAX           4000 non-null   float64
#  9   PTRATIO       4000 non-null   float64
#  10  IMM           4000 non-null   float64
#  11  BPL           4000 non-null   float64
#  12  PRICE         4000 non-null   float64
#  13  RIVERSIDE     4000 non-null   object
# dtypes: float64(12), int64(1), object(1)
# memory usage: 437.6+ KB

# %%
np.average(df.PRICE)
# Out:
# np.float64(24.355923220694248)

# %%
df.describe()

# %%
np.average(df.PRICE.sort_values(ascending=False).iloc[:10])
# Out:
# np.float64(52.36590175716407)

# %%
(df['RM']==-1).sum()
(df['RM']==2).sum()
# Out:
# np.int64(40)

# %%
{(df['AGE'] <1).sum()}
# Out:
# {np.int64(50)}

# %%
(df['RIVERSIDE']=='UNKNOWN').sum()
# Out:
# np.int64(88)

# %%
df['RIVERSIDE'] = df['RIVERSIDE'].replace('UNKNOWN', np.nan)
df.loc[df['AGE'] < 0, 'AGE'] = np.nan
df2=df.dropna(subset=['RIVERSIDE','AGE'])
((df2['AGE']<=50)&(df2['RIVERSIDE']=="YES")).sum()
# Out:
# np.int64(44)

# %%
((df['HIGHWAYCOUNT'] ==6) |(df['HIGHWAYCOUNT'] ==8)| (df['HIGHWAYCOUNT'] ==7)).sum()
# Out:
# np.int64(1211)

# %%
def category(PRICE):
  if PRICE<10:
    return "Category 1"
  if 20>PRICE>=10:
    return "Category 2"
  if 30>PRICE>=20:
    return "Category 3"

  if 40>PRICE>=30:
    return "Category 4"
  else:
    return "Category 5"
df["CATEGORY"]=df['PRICE'].apply(category)
df.head()
df['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Category 3    2028
# Category 2    1158
# Category 4     503
# Category 5     268
# Category 1      43
# Name: count, dtype: int64

# %%
df['RIVERSIDE']=df['RIVERSIDE'].replace('UNKNOWN',np.nan)
df.loc[df['RM'] < 0, 'RM'] = np.nan
df.loc[df['AGE'] < 0, 'AGE'] = np.nan

# %%
Y=df['PRICE']
X=df.iloc[:,:-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
X_train.shape,Y_train.shape,Y_test.shape,X_test.shape
# Out:
# ((2800, 13), (2800,), (1200,), (1200, 13))

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
mm.fit_transform(df[['CRIM','ZN','POLINDEX','DIS','HIGHWAYCOUNT','TAX','PTRATIO','IMM','BPL']])

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='median')
imp.fit_transform(df[['RM']])

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='mean')
imp.fit_transform(df[['AGE']])

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()


mm.fit_transform(df[['AGE','RM']])

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
imp.fit_transform(df[['RIVERSIDE']])

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit_transform(df[['RIVERSIDE']])

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
std.fit_transform(df[["INDUS"]])

# %%
X_test.mean().mean()
# Out:
# np.float64(70.62772645199297)
