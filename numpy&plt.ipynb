# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushan-ssh/colabs/blob/main/numpy%26plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(0,1,10)
y=x
plt.plot(x, y)
plt.scatter(x, y)
plt.title("Linear Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.grid()

# %%
plt.plot(x,y);
plt.title("Linear Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.scatter(x,y);
plt.title("Linear Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
x=np.linspace(-1,1,20)
y=x**2
plt.plot(x,y);
plt.scatter(x,y);
plt.title("Linear Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
M = np.array([[1,2],[3,4]])
print(M)

N = np.array([[5,2],[8,4]])
print(N)

print(M+N)
# Out:
# [[1 2]
#  [3 4]]
# [[5 2]
#  [8 4]]
# [[ 6  4]
#  [11  8]]

# %%
print((M*N)*(M*N))
# Out:
# [[ 25  16]
#  [576 256]]

# %%
plt.bar(x, y)
plt.title("Bar Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate data for a 3D surface plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_title("Exciting 3D Surface Plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate data for a 3D scatter plot
n_points = 50
x = np.random.rand(n_points) * 10 - 5
y = np.random.rand(n_points) * 10 - 5
z = np.sin(np.sqrt(x**2 + y**2)) + np.random.rand(n_points) * 0.5

# Create the 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, c=z, cmap='magma', marker='o')

ax.set_title("Another Exciting 3D Scatter Plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")

plt.show()
